# %% [markdown]
# <a href="https://colab.research.google.com/github/HimAir10/Pw-skillsAssignment/blob/main/Data_Toolkit_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Theory Questions:**

# %% [markdown]
# 1. What is Numpy and why it is widely used in python?
#
#   Ans. Numpy is a library in python which is responsible for all type of mathematical operation on the data and also provide faster computation speed for various kind of mathematical operations like calculating mean, median, mode and matrix multiplication etc.

# %% [markdown]
# 2. How does broadcasting work in NumPy?
#   Ans. Broadcasting in numpy refers to the process of apply various arithmetic operation on array of different shapes.
#
#   Broadcasting Rules -
#
#   Numpy compares shape from right to left(trailing dimensions) and apply the following rules-->
#   1. if dimension are equal, they are compatible
#   2. if one of dimension is 1, then it stretches itself to match other
#   3. if both are of diff dimension then error will be thrown.

# %% [markdown]
# 3. What is Pandas Dataframe?
#
#   Ans. Pandas is a library in python which is responsible for data manipulation methods, like deleting null values, droping columns, feature engineering, etc. and Pandas Dataframe represents the data in the form of rows and columns, and makes data accessible for performing different kinds of data operations on it.

# %% [markdown]
# 4. Explain the use of the groupby() method in Pandas.
#
#   Ans. In Pandas groupby() separate the dataframe into the groups on the basis of some criteria, (e.g. values in one or more columns),
#   For Example - df = pd.DataFrame({'class':['A','B','A','B','B','B','A'],'Values':[1,2,3,4,5,6,7]}) this creates a dataframe in which there are values corresponding to two classes, so groupby in this does the following- df.groupby('class').count()
#
#
#   ![Screenshot 2025-06-11 at 7.32.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# 5. Why is Seaborn Preffered for statistical visualization?
#
#   Ans. Seaborn and Matplotlib both are the visualization tools in python which helps in extracting insights from the data, but the seaborn is more advanced visualization tool in python which offers visualization in more enhanced way, there is so much of exciting plots offered by the seaborn which gives a key advantage of using seaborn in statistical visualization.

# %% [markdown]
# 6. What are the differences between Numpy arrays and Python Lists?
#
#   Ans. Lists in the python is a data structure to store data of all data types e.g. int,float,string,bool etc. whereas in numpy it stores element of homogeneous data type only.
#
#   Mathematical operations on list takes a lot of computation time for large amount of data.
#   wherea Numpy is written on C programming which provides faster computation.

# %% [markdown]
# 7. What is Heatmap and when it should be used?
#
#   Ans. Heatmap is the correlation matrix which represents the relationship between the variables of a dataframe, it is used when we want to know the trend between the numerical columns of a dataframe that one column is negatively correlated with the other columns or positively correlated.

# %% [markdown]
# 8. What does the term "vectorized operation" mean in NumPy?
#
#   Ans.Vectorized operations in NumPy allow you to apply operations (like addition, multiplication) directly to entire arrays without using loops. These operations are fast because they are implemented in low-level C code behind the scenes.

# %% [markdown]
# 9. How does Matplotlib differ from Plotly?
#
#   Ans. | Feature       | Matplotlib             | Plotly                 |
# | ------------- | ---------------------- | ---------------------- |
# | Type          | Static, 2D plots       | Interactive, web-based |
# | Interactivity | Low                    | High                   |
# | Output        | PNG, PDF, etc.         | HTML, Dash apps        |
# | Ease of use   | Simple for basic plots | Requires more setup    |

# %% [markdown]
# 10. What is the significance of hierarchical indexing in Pandas?
#
#   Ans. Hierarchical indexing allows you to have multiple (multi-level) index levels on rows or columns, enabling better organization and selection of complex data (like time-series or grouped data).

# %% [markdown]
# 11. What is the role of Seaborn's pairplot() function?
#
#   Ans.pairplot() creates a matrix of scatter plots for each pair of features in a DataFrame, along with histograms on the diagonal. It's useful for visualizing relationships in multivariate datasets.

# %% [markdown]
# 12. What is the purpose of the describe() function in Pandas?
#
#   Ans.The describe() function provides a quick statistical summary of numeric (or categorical) columns, including count, mean, std, min, and percentiles.

# %% [markdown]
# 13. Why is handling missing data important in Pandas?
#
#   Ans. Handling missing data is crucial because:
#
#   - It can bias results if not treated properly.
#   -  Many algorithms can’t handle NaNs.
#   - It improves data quality and model accuracy.

# %% [markdown]
# 14. What are the benefits of using Plotly for data visualization?
#
#   Ans. Interactivity: Zoom, pan, hover info.
# Web integration: Outputs to HTML.
# 3D plots: Easily created.
# Dashboarding: Works with Dash.

# %% [markdown]
# 15. How does NumPy handle multidimensional arrays?
#
#   Ans.NumPy uses the ndarray object, which can be 1D, 2D, or nD. Operations work across dimensions efficiently due to broadcasting.

# %% [markdown]
# 16. What is the role of Bokeh in data visualization?
#
#   Ans. Bokeh is a Python library for creating interactive and real-time plots in web browsers. It supports streaming data and custom JavaScript callbacks.

# %% [markdown]
# 17. Explain the difference between apply() and map() in Pandas.
#
# Ans.                     |
# | `map()`     | Series only      | Element-wise transformations    |
#
# | `apply()` | Series/DataFrame | Row/column-wise or element-wise |

# %% [markdown]
# 18. What are some advanced features of NumPy?
#
# Ans.
# - Broadcasting
#
# - Masked arrays
# -Memory mapping
# -Vectorized linear algebra (np.linalg)
# -FFT, random sampling
# -Structured arrays

# %% [markdown]
# 19. How does Pandas simplify time series analysis?
#
# Ans.
# - Built-in datetime index handling (DatetimeIndex)
# -Date parsing & resampling (resample())
# -Rolling window stats (rolling())
# -Shifting/lagging data

# %% [markdown]
# 20. What is the role of a pivot table in Pandas?
#
# Ans.
# Pivot tables summarize data by grouping and aggregating it. It’s similar to Excel pivot tables.

# %% [markdown]
# # **Practical Questions**

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
for i in range(arr.shape[0]):
  print(np.sum(arr[i]))
# Out:
# 6
# 15

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4,5],'col2':[4,5,2,6,7],'col3':[8,9,5,7,4]})
df[['col1']].mean()
# Out:
# col1    3.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(x = df['col1'],y = df['col2'])

# %%
import seaborn as sns
df.corr()
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame({'Name':['Himanshu','Ajay','Bijay','Sanjay','Alex'], 'Age':[21,22,18,19,20], 'Salary':[10000000,20000,30000,35000,50000]})

# %%
df1
# Out:
#        Name  Age    Salary
# 0  Himanshu   21  10000000
# 1      Ajay   22     20000
# 2     Bijay   18     30000
# 3    Sanjay   19     35000
# 4      Alex   20     50000

# %%
df1['New_age'] = df1['Age']+5

# %%
df1
# Out:
#        Name  Age    Salary  New_age
# 0  Himanshu   21  10000000       26
# 1      Ajay   22     20000       27
# 2     Bijay   18     30000       23
# 3    Sanjay   19     35000       24
# 4      Alex   20     50000       25

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-2356223829> in <cell line: 0>()
# ----> 1 arr1 = np.linspace(1,10,(3,3))
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     125
#     126     """
# --> 127     num = operator.index(num)
#     128     if num < 0:
#     129         raise ValueError(
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
import random
arr1 = np.random.rand(2,3)
print(arr1)

arr2 = np.random.rand(2,3)
print(arr2)

print(np.multiply(arr1,arr2))
# Out:
# [[0.1532761  0.5446229  0.4087585 ]
#  [0.83822661 0.23216248 0.47872684]]
# [[0.44268323 0.07414296 0.49520585]
#  [0.69797384 0.90291236 0.87757854]]
# [[0.06785276 0.04037996 0.2024196 ]
#  [0.58506024 0.20962237 0.4201204 ]]

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y1 = [5,1,7,8,10]
y2 = [7,8,3,5,1]
plt.plot(x,y1,color = 'red',marker = 'o',label = 'prices of Tata motors')
plt.plot(x,y2,color = 'blue',marker = 'o',label = 'prices of Tata power')
plt.title('line chart to understand the syntax')
plt.xlabel('day interval as x points')
plt.ylabel('price as y points')
plt.grid()
plt.legend()
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'col1':[10,20,15,16,19],'col2':[13,18,23,24,25],'col3':[12,14,16,20,29]})

# %%
df
# Out:
#    col1  col2  col3
# 0    10    13    12
# 1    20    18    14
# 2    15    23    16
# 3    16    24    20
# 4    19    25    29

# %%
df1 = df[df>15]
df1
# Out:
#    col1  col2  col3
# 0   NaN   NaN   NaN
# 1  20.0  18.0   NaN
# 2   NaN  23.0  16.0
# 3  16.0  24.0  20.0
# 4  19.0  25.0  29.0

# %%
df1.dropna()
# Out:
#    col1  col2  col3
# 3  16.0  24.0  20.0
# 4  19.0  25.0  29.0

# %%
import seaborn as sns
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
import numpy as np

# %%
mat1 = np.array([[1,2],[3,4]])
mat1.shape
# Out:
# (2, 2)

# %%
mat2 = np.array([[4,5],[6,7]])
mat2.shape
# Out:
# (2, 2)

# %%
result = mat1 @ mat2

# %%
result
# Out:
# array([[16, 19],
#        [36, 43]])

# %%
import pandas as pd
df = pd.read_csv('/content/Bank_churn.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...
